# %% [markdown]
# Analyze h5 files generated by pyfolio analyzer

# %%
import pandas as pd
# %matplotlib inline

# %%
return_df = pd.read_hdf('return.h5')

# %%
return_df.plot(figsize=(16, 9))

# %%
return_df.plot.hist(bins=30, figsize=(16, 9))

# %%
return_df.describe()
# Out:
# count    347.000000
# mean       0.000066
# std        0.002066
# min       -0.013297
# 25%       -0.000744
# 50%        0.000075
# 75%        0.000708
# max        0.010953
# Name: return, dtype: float64

# %%
return_df.mean()/(return_df.std()/len(return_df)** 0.5)
# Out:
# 0.5929834611897677

# %%
pd.read_hdf('positions.h5')
# Out:
#                            Data0          cash
# Datetime
# 2019-05-05 00:00:00+00:00    0.0  20000.000000
# 2019-05-06 00:00:00+00:00    0.0  20000.000000
# 2019-05-07 00:00:00+00:00    0.0  20000.000000
# 2019-05-08 00:00:00+00:00    0.0  20000.000000
# 2019-05-09 00:00:00+00:00    0.0  20000.000000
# ...                          ...           ...
# 2020-06-08 00:00:00+00:00    1.0  20371.159182
# 2020-06-09 00:00:00+00:00    1.0  20371.409182
# 2020-06-10 00:00:00+00:00    1.0  20303.659182
# 2020-06-11 00:00:00+00:00    1.0  20409.108529
# 2020-06-12 00:00:00+00:00    1.0  20445.608529
#
# [347 rows x 2 columns]

# %%
pd.read_hdf('transactions.h5')
# Out:
#                            amount        price  sid symbol        value
# date
# 2019-05-13 00:00:00+00:00      -1  2856.321125    0         2856.321125
# 2019-05-17 00:00:00+00:00       2  2870.684625    0        -5741.369250
# 2019-05-23 00:00:00+00:00      -2  2845.576500    0         5691.153000
# 2019-05-28 00:00:00+00:00       2  2839.419000    0        -5678.838000
# 2019-05-29 00:00:00+00:00      -2  2794.602000    0         5589.204000
# 2019-06-05 00:00:00+00:00       2  2813.906250    0        -5627.812500
# 2019-06-13 00:00:00+00:00      -2  2875.561500    0         5751.123000
# 2019-06-14 00:00:00+00:00       2  2898.198375    0        -5796.396750
# 2019-06-26 00:00:00+00:00      -2  2918.789875    0         5837.579750
# 2019-06-30 00:00:00+00:00       2  2962.230375    0        -5924.460750
# 2019-07-09 00:00:00+00:00      -2  2961.768375    0         5923.536750
# 2019-07-11 00:00:00+00:00       2  3003.751125    0        -6007.502250
# ...
